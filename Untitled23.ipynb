# %% [markdown]
# <a href="https://colab.research.google.com/github/amit-sahu-a11y/ML_projects_for_practice/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
class scratch_linear_regression:
  def __init__(self,no_iter=1000,lr=0.01):
    self.no_iter=no_iter
    self.lr=lr

  def fit(self,x,y):
    self.x=x
    self.y=y
    self.m,self.n=x.shape
    self.w=np.zeros(self.n)
    self.b=0


    for i in range(self.no_iter):
      self.weight()

  def weight(self):
    y_pred=self.prediction(self.x)
    dw=-2*(self.x.T).dot(self.y-y_pred)/self.m
    db=-2*np.sum(self.y-y_pred)/self.m
    self.w=self.w-self.lr*dw
    self.b=self.b-self.lr*db


  def prediction(self,x):
    return x.dot(self.w)+self.b

# %%
model=scratch_linear_regression()

# %%
df=pd.read_csv('/content/sample_data/california_housing_train.csv')
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
x=df.drop(columns='median_income',axis=1)
y=df['median_income']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)

# %%
x.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_house_value    0
# dtype: int64

# %%
type(x),type(y)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
model.fit(x_scaled,y)

# %%
model.b
# Out:
# np.float64(3.8835780934640654)

# %%
model.w
# Out:
# array([ 0.0609691 ,  0.04401737, -0.29330076,  1.53292868, -1.15601597,
#         0.16798102, -0.5773003 ,  1.25505127])

# %%
model_pred=model.prediction(x_scaled)

# %%
from sklearn.metrics import r2_score

# %%
final=r2_score(y,model_pred)

# %%
final
# Out:
# 0.6530747617837794

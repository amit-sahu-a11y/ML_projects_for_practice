# %% [markdown]
# <a href="https://colab.research.google.com/github/amit-sahu-a11y/ML_projects_for_practice/blob/main/Data_Type.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #there is so many datatypes operations. let's see

# %%
# is eqaul to
print("5"=="5")
print(5=="5")

# %%
# not eqaul to
print(5!="5")
print("5"!="5")

# %%
# greater than
print(5>5)
print(5>6)
print(6>5)

# %%
# less than
print(5<6)
print(5<4)

# %%
a=int(input("Enter the First Number!"))
b=int(input("Enter the Second Number"))
s=input("Enter the operator which must be following one them(* or + or - or / or %)")

if s=="*":
  print(a*b)
elif s=="+":
  print()
# Out:
# Enter the First Number!2
# Enter the Second Number2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1624/1659574915.py in <cell line: 0>()
#       1 a=int(input("Enter the First Number!"))
#       2 b=int(input("Enter the Second Number"))
# ----> 3 s=input("Enter the operator which must be following one them(* or + or - or / or %)")
#       4
#       5 if s=="*":
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %%
my_set={1,2,4,3,2,1}
print(type(my_set))

# %%
my_dict={}
print(type(my_dict))

# %%
my_set.add(0)
print(my_set)

# %%
my_set.remove(1)
print(my_set)

# %%
my_set.discard(9)
print(my_set)

# %%
s1={1,3,4,42,5}
s2={6,4,3,6,7,8}
s1.union(s2)

# %%
# intersection
s1.intersection(s2)

# %%
dic_may={
    "name":"amit",
    "age":23,

}
print(dic_may)
print(dic_may['name'])
print(dic_may.get("name"))
print(dic_may.values())
print(dic_may.items())
print(dic_may.keys())
dic_may["name"]="rohan"
print(dic_may)
dic_may['number']=324422
print(dic_may)

# %% [markdown]
# ### tuple

# %%
my_tuple=(1,3,4,5,5,4)
print(type(my_tuple))

# %%
li=list(my_tuple)
print(type(li))

# %%
# my_tuple[1]=5

# %%
print(my_tuple.count(1))
print(my_tuple.index(3))

# %% [markdown]
# #packing and unpacking

# %%
my_tuple

# %%
packed=1,"dnf",344, 3849494, 3493938, 337373
print(packed)
print(type(packed))

# %%
a,b,c=packed
print(a)
print(b)
print(c)

# %%
# that is callled a *method
packed

# %%
a,*b,c=packed
print(a)
print(b)
print(c)

# %% [markdown]
# ###function

# %%
def check_even(num):
  if num>18:
    print("voted")
  else:
    print('not voted')
check_even(10)
# Out:
# not voted

# %%
def par(*args):
  print(args)
par(1,2,3,4,4,2,3)
# Out:
# (1, 2, 3, 4, 4, 2, 3)

# %%
def key(**kwargs):
  print(kwargs)
key(anme="ami", age=39)
# Out:
# {'anme': 'ami', 'age': 39}

# %%
def tem_conversion(value,unit):
  if unit=="c":
    return (c*1.8)+32
  else:
    return (value-32)*0.55

tem_conversion(40,"r")
# Out:
# 4.4

# %%
def password_checker(pasword):

# %%
a=2
b=4
h=lambda a,b:a*b
print(h(a,b))
# Out:
# 8

# %%
num=17
if num>1 and all(num%i !=0 for i in range(2,num)):
  print("prime")
else:
  print("not prime")
# Out:
# prime

# %%
n=10
for i in range(n):
  if n%2==0:
    print("not prime")
    break
else:
  print("it's a prime number")
# Out:
# not prime

# %%
number=370
n_str=str(number)
l=len(n_str)
sum=0
for i in range(len(n_str)):
  sum += int(n_str[i])**l
print(sum)
# Out:
# 370

# %% [markdown]
# <a href="https://colab.research.google.com/github/amit-sahu-a11y/ML_projects_for_practice/blob/main/Data_Type.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #there is so many datatypes operations. let's see

# %%
# is eqaul to
print("5"=="5")
print(5=="5")
# Out:
# True
# False

# %%
# not eqaul to
print(5!="5")
print("5"!="5")
# Out:
# True
# False

# %%
# greater than
print(5>5)
print(5>6)
print(6>5)
# Out:
# False
# False
# True

# %%
# less than
print(5<6)
print(5<4)
# Out:
# True
# False

# %%
a=int(input("Enter the First Number!"))
b=int(input("Enter the Second Number"))
s=input("Enter the operator which must be following one them(* or + or - or / or %)")

if s=="*":
  print(a*b)
elif s=="+":
  print()

# %%
my_set={1,2,4,3,2,1}
print(type(my_set))
# Out:
# <class 'set'>

# %%
my_dict={}
print(type(my_dict))
# Out:
# <class 'dict'>

# %%
my_set.add(0)
print(my_set)
# Out:
# {0, 1, 2, 3, 4}

# %%
my_set.remove(1)
print(my_set)
# Out:
# {0, 3, 4}

# %%
my_set.discard(9)
print(my_set)
# Out:
# {0, 3, 4}

# %%
s1={1,3,4,42,5}
s2={6,4,3,6,7,8}
s1.union(s2)
# Out:
# {1, 3, 4, 5, 6, 7, 8, 42}

# %%
# intersection
s1.intersection(s2)
# Out:
# {3, 4}

# %%
dic_may={
    "name":"amit",
    "age":23,

}
print(dic_may)
print(dic_may['name'])
print(dic_may.get("name"))
print(dic_may.values())
print(dic_may.items())
print(dic_may.keys())
dic_may["name"]="rohan"
print(dic_may)
dic_may['number']=324422
print(dic_may)
# Out:
# {'name': 'amit', 'age': 23}
# amit
# amit
# dict_values(['amit', 23])
# dict_items([('name', 'amit'), ('age', 23)])
# dict_keys(['name', 'age'])
# {'name': 'rohan', 'age': 23}
# {'name': 'rohan', 'age': 23, 'number': 324422}

# %% [markdown]
# <a href="https://colab.research.google.com/github/amit-sahu-a11y/ML_projects_for_practice/blob/main/tkpi_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
exec(open("/content/tkpi_predictor_colab.py").read())

# %%
train_all_models("/content/perf_data_09_08.csv")
# Out:
# ...
# TARGET: cpi
# Train: 2026-05-13 and earlier | Test: 2026-05-14 onward
# Rows: train=22,572, test=10,615
# R²   : 0.4142
# MAE  : 2.633706
# RMSE : 5.077861
# Model: /content/models/tkpi_model_cpi.joblib
# The requested R² > 0.75 was NOT achieved honestly on the chronological holdout. Do not add installs/revenue/retention users or current target KPIs just to raise R²; that would create leakage.
# ...
#
# ...
# TARGET: roas_d1
# Train: 2026-05-13 and earlier | Test: 2026-05-14 onward
# Rows: train=24,025, test=15,170
# R²   : -0.0001
# MAE  : 0.252094
# RMSE : 8.768448
# Model: /content/models/tkpi_model_roas_d1.joblib
# The requested R² > 0.75 was NOT achieved honestly on the chronological holdout. Do not add installs/revenue/retention users or current target KPIs just to raise R²; that would create leakage.
# ...
#
# ...
# TARGET: roas_d7
# Train: 2026-05-13 and earlier | Test: 2026-05-14 onward
# Rows: train=24,025, test=15,170
# R²   : 0.0000
# MAE  : 0.668869
# RMSE : 38.695687
# ...

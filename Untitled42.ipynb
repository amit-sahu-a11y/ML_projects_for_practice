# %% [markdown]
# <a href="https://colab.research.google.com/github/amit-sahu-a11y/ML_projects_for_practice/blob/main/Untitled42.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Displaying Outliers
#
# Outliers are data points that significantly differ from other observations. They can occur due to measurement errors, data entry errors, or genuinely rare events. Identifying and understanding outliers is crucial in data analysis as they can skew results and mislead conclusions.
#
# One common method to detect outliers is the **Interquartile Range (IQR)** method.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Create a sample DataFrame with some potential outliers
data = {
    'Value': [10, 12, 11, 13, 10, 14, 15, 12, 100, 11, 9, 13, 14, 10, -5, 12],
    'Category': ['A', 'A', 'A', 'A', 'B', 'B', 'B', 'B', 'A', 'A', 'B', 'B', 'A', 'A', 'B', 'A']
}
df = pd.DataFrame(data)

print("Sample DataFrame:")
display(df)
# Out:
# Sample DataFrame:
#     Value Category
# 0      10        A
# 1      12        A
# 2      11        A
# 3      13        A
# 4      10        B
# 5      14        B
# 6      15        B
# 7      12        B
# 8     100        A
# 9      11        A
# 10      9        B
# 11     13        B
# 12     14        A
# 13     10        A
# 14     -5        B
# 15     12        A

# %% [markdown]
# ### Outlier Detection using the IQR Method
#
# The IQR method defines outliers as any data points that fall below `Q1 - 1.5 * IQR` or above `Q3 + 1.5 * IQR`.
#
# -   **Q1**: The first quartile (25th percentile).
# -   **Q3**: The third quartile (75th percentile).
# -   **IQR**: Interquartile Range (Q3 - Q1).

# %%
# Calculate Q1, Q3, and IQR for the 'Value' column
Q1 = df['Value'].quantile(0.25)
Q3 = df['Value'].quantile(0.75)
IQR = Q3 - Q1

# Define outlier bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Q1: {Q1}")
print(f"Q3: {Q3}")
print(f"IQR: {IQR}")
print(f"Lower Bound (Outlier threshold): {lower_bound}")
print(f"Upper Bound (Outlier threshold): {upper_bound}")

# Identify outliers
outliers = df[(df['Value'] < lower_bound) | (df['Value'] > upper_bound)]

print("\nIdentified Outliers:")
display(outliers)
# Out:
# Q1: 10.0
# Q3: 13.25
# IQR: 3.25
# Lower Bound (Outlier threshold): 5.125
# Upper Bound (Outlier threshold): 18.125
#
# Identified Outliers:
#     Value Category
# 8     100        A
# 14     -5        B

# %% [markdown]
# ### Visualizing Outliers
#
# Box plots are excellent for visualizing the distribution of numerical data and clearly showing outliers. Data points outside the 'whiskers' of the box plot are typically considered outliers.

# %%
# Box plot to visualize outliers
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['Value'], color='skyblue')
plt.title('Box Plot of Values to Show Outliers')
plt.ylabel('Value')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# A scatter plot can also be useful, especially when comparing two variables or when you want to highlight the specific outlier points in relation to the rest of the data.

# %%
# Scatter plot to highlight outliers
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df.index, y=df['Value'], color='blue', label='Normal Data')
sns.scatterplot(x=outliers.index, y=outliers['Value'], color='red', marker='X', s=100, label='Outliers')

# Optional: Add a line for the upper and lower bounds
plt.axhline(y=upper_bound, color='green', linestyle='--', label='Upper Bound')
plt.axhline(y=lower_bound, color='orange', linestyle='--', label='Lower Bound')

plt.title('Scatter Plot with Highlighted Outliers')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# These visualizations help in understanding the extent and nature of outliers in your dataset.

# %% [markdown]
# ### Histogram of 'Value' Column
#
# A histogram displays the distribution of a numerical variable by dividing the data into bins and showing the frequency of observations within each bin. It's great for understanding the shape, spread, and central tendency of your data.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Value'], kde=True, bins=10, color='purple')
plt.title('Distribution of Values (Histogram)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### Bar Chart of Mean 'Value' by 'Category'
#
# Bar charts are excellent for comparing discrete categories. Here, we'll calculate the mean 'Value' for each 'Category' and display it to understand if there's a significant difference in average values between categories.

# %%
# Calculate the mean 'Value' for each 'Category'
mean_value_by_category = df.groupby('Category')['Value'].mean().reset_index()

plt.figure(figsize=(8, 6))
sns.barplot(x='Category', y='Value', data=mean_value_by_category, palette='viridis')
plt.title('Mean Value by Category')
plt.xlabel('Category')
plt.ylabel('Mean Value')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

display(mean_value_by_category)
# Out:
# /tmp/ipykernel_1770/1408220841.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Category', y='Value', data=mean_value_by_category, palette='viridis')
#   Category      Value
# 0        A  21.444444
# 1        B   9.714286

# %% [markdown]
# <a href="https://colab.research.google.com/github/amit-sahu-a11y/ML_projects_for_practice/blob/main/Untitled27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f=open('/content/sample_data/README.md','')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1532/712433968.py in <cell line: 0>()
# ----> 1 f=open('/content/sample_data/README.md','')
#
# ValueError: Must have exactly one of create/read/write/append mode and at most one plus

# %%
f.read()

# %%
f.write('hello')

# %%
# f.readline()

# %%
f.read()
# Out:
# ''

# %%
f2=open('hello.txt','w')
f2.write('hello, how are you ! \nmy name you \nyou are better than me ')
# Out:
# 58

# %%
with open('hello.txt','r') as f3:
  df=f3.read()
new_df=df.replace('you','view')

# %%
with open('hello.txt','w') as f4:
  f4.write(new_df)

# %%
with open('hello.txt','r') as f5:
  fin=f5.readline()
  if fin.find('better') != -1:
    print('found')

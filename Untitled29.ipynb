# %% [markdown]
# <a href="https://colab.research.google.com/github/amit-sahu-a11y/ML_projects_for_practice/blob/main/Untitled29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# linearRegression has 2 type:
# 1. simple LR
# 2. Multi LR
#
# simple LR formula is w=(x-x.mean())(y-y.mean())/(x-x.mean())^2
#
# multi LR formula is b= (x.T,x)`1 (x.T,y)

# %% [markdown]
# Ridge(L2 Penatly):
# LR formula is w=(x-x.mean())(y-y.mean())/(x-x.mean())^2 + lemda(w.T,W)
